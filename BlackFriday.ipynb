# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df.drop(['Product_ID','Stay_In_Current_City_Years'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    User_ID Gender   Age  Occupation City_Category  Marital_Status  \
# 0  1000001      F  0-17          10             A               0
# 1  1000001      F  0-17          10             A               0
# 2  1000001      F  0-17          10             A               0
# 3  1000001      F  0-17          10           NaN               0
# 4  1000002      M   55+          16             C               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                   3                 NaN                 NaN      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 NaN                 NaN      1422
# 3                  12                14.0                 NaN      1057
# 4                   8                 NaN                 NaN      7969

# %%
df.head(20)
# Out:
#     User_ID Gender    Age  Occupation City_Category  Marital_Status  \
# 0   1000001      F   0-17          10             A               0
# 1   1000001      F   0-17          10             A               0
# 2   1000001      F   0-17          10             A               0
# 3   1000001      F   0-17          10           NaN               0
# 4   1000002      M    55+          16             C               0
# 5   1000003      M  26-35          15             A               0
# 6   1000004      M  46-50           7           NaN               1
# 7   1000004      M  46-50           7             B               1
# 8   1000004      M  46-50           7             B               1
# 9   1000005      M  26-35          20             A               1
# 10  1000005      M  26-35          20             A               1
# 11  1000005      M  26-35          20           NaN               1
# 12  1000005      M  26-35          20             A               1
# ...

# %%
df['City_Category']=df['City_Category'].fillna('X')

# %%
df.head()
# Out:
#    User_ID Gender   Age  Occupation City_Category  Marital_Status  \
# 0  1000001      F  0-17          10             A               0
# 1  1000001      F  0-17          10             A               0
# 2  1000001      F  0-17          10             A               0
# 3  1000001      F  0-17          10             X               0
# 4  1000002      M   55+          16             C               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                   3                 NaN                 NaN      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 NaN                 NaN      1422
# 3                  12                14.0                 NaN      1057
# 4                   8                 NaN                 NaN      7969

# %%
df.dtypes
# Out:
# User_ID                 int64
# Gender                 object
# Age                    object
# Occupation              int64
# City_Category          object
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Product_Category_3    float64
# Purchase                int64
# dtype: object

# %%
df['City_Category']=df['City_Category'].map({
    'A':'Metro Cities',
    'B':'Small Towns',
    'C':'Villages',
    'X':'Unknown'
})

# %%
df.head(15)
# Out:
#     User_ID Gender    Age  Occupation City_Category  Marital_Status  \
# 0   1000001      F   0-17          10  Metro Cities               0
# 1   1000001      F   0-17          10  Metro Cities               0
# 2   1000001      F   0-17          10  Metro Cities               0
# 3   1000001      F   0-17          10       Unknown               0
# 4   1000002      M    55+          16      Villages               0
# 5   1000003      M  26-35          15  Metro Cities               0
# 6   1000004      M  46-50           7       Unknown               1
# 7   1000004      M  46-50           7   Small Towns               1
# 8   1000004      M  46-50           7   Small Towns               1
# 9   1000005      M  26-35          20  Metro Cities               1
# 10  1000005      M  26-35          20  Metro Cities               1
# 11  1000005      M  26-35          20       Unknown               1
# 12  1000005      M  26-35          20  Metro Cities               1
# ...

# %%
df.rename(columns={'Product_Category_1':'Baseball Caps','Product_Category_2':'Wine tubmlers','Product_Category_3':'Pet Raincoats'},inplace=True)

# %%
df.head()

# %%
df['Marital_Status']=df['Marital_Status'].map({
    0:'UnMarried',
    1:'Married'
})

# %%
df.head(15)

# %%
interval=(0,8,12,24)
categories=['<8','8-12','>12']
df['ball_cut']=pd.cut(df['Baseball Caps'],interval,labels=categories)
ax=sns.countplot(x='Gender',hue='ball_cut',data=df)
ax.set(title='Try',xlabel='Gender',ylabel='Number')
plt.show()

# %%
ax=sns.countplot(x='Gender',hue='City_Category',data=df)
ax.set(title='City wise male and female',xlabel='Gender',ylabel='Number')

# %%
ax=sns.countplot(data=df[df[]])

# %%
import seaborn as sns 
sns.get_dataset_names()
# Out:
# C:\Users\Avani Vaishnav\Anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\Avani Vaishnav\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
